# %%
usuarios = 1500
promedio_compras = 45.5
productos = "Refrigerador"
compras_mes= "20"
tiene_stock = True

print(f"El tipo de 'promedio_compras' es {type(promedio_compras)}")
print(f"El tipo de 'productos' es {type(productos)}")
print(f"El tipo de 'tiene_stock' es {type(tiene_stock)}")
print(f"El tipo de 'usuarios' es {type(usuarios)}")
# Out:
# El tipo de 'promedio_compras' es <class 'float'>
# El tipo de 'productos' es <class 'str'>
# El tipo de 'tiene_stock' es <class 'bool'>
# El tipo de 'usuarios' es <class 'int'>
