# %%
import torch
from transformers import pipeline

device = "mps" if torch.backends.mps.is_available() else "cpu"
print(f"Usando dispositivo: {device}")

nlp = pipeline("sentiment-analysis", device=device)

textos = ["Me encanta el procesamiento del lenguaje Natural, es fascinante",
          "Esta materia me parece muy difícil y no entiendo nada",
          "El profesor muestra clases divertidas",
          "El examen estuvo mas o menos bien!, aunque algunas preguntas fueron raras"]

for texto in textos:
    resultado = nlp(texto)[0]
    print(f"Texto: '{texto}'")
    print(f"Sentimiento: {resultado['label']} (Confianza: {resultado['score']:.4f})\n")
    print("-"*60)
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Usando dispositivo: mps
# Device set to use mps
# Texto: 'Me encanta el procesamiento del lenguaje Natural, es fascinante'
# Sentimiento: POSITIVE (Confianza: 0.9415)
#
# ------------------------------------------------------------
# Texto: 'Esta materia me parece muy difícil y no entiendo nada'
# Sentimiento: NEGATIVE (Confianza: 0.9452)
#
# ------------------------------------------------------------
# Texto: 'El profesor muestra clases divertidas'
# Sentimiento: POSITIVE (Confianza: 0.8507)
#
# ------------------------------------------------------------
# Texto: 'El examen estuvo mas o menos bien!, aunque algunas preguntas fueron raras'
# Sentimiento: NEGATIVE (Confianza: 0.9247)
#
# ------------------------------------------------------------

# %%
import spacy
nlp = spacy.load("es_core_news_sm")

oraciones = ["El banco esta cerca del parque",
            "El banco me dio un préstamo",
            "El banco estaba ocupado",
            ]

for oracion in oraciones:
    doc = nlp(oracion)
    print(f"\nOración: '{oracion}'")
    print(f"Tokens: {[token.text for token in doc]}")
    entidades = [(ent.text, ent.label_) for ent in doc.ents]
    print(f"Entidades reconocidas: {entidades if entidades else 'Ninguna encontrada'}")
# Out:
# Oración: 'El banco esta cerca del. parque'
# Tokens: ['El', 'banco', 'esta', 'cerca', 'del', '.', 'parque']
# Entidades reconocidas: Ninguna encontrada
#
# Oración: 'El banco me dio un préstamo'
# Tokens: ['El', 'banco', 'me', 'dio', 'un', 'préstamo']
# Entidades reconocidas: Ninguna encontrada
#
# Oración: 'El banco estaba ocupado'
# Tokens: ['El', 'banco', 'estaba', 'ocupado']
# Entidades reconocidas: Ninguna encontrada

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
import nltk
nltk.download('punkt_tab')


texto = "¡Hola! ¿Cómo estás? Espero que estés teniendo un buen día niño. El procesamiento del lenguaje natural es increíble."

#TOKENIZAR

oraciones = sent_tokenize(texto)
print(f"Oraciones: {len(oraciones)}")

for i, oracion in enumerate(oraciones):
    print(f"Oración {i}: {oracion}")
    print()

tokens = word_tokenize(texto)
print(f"Tokens: {len(tokens)}")
print(f"Tokens: {tokens}")

from nltk.corpus import stopwords
nltk.download('stopwords')
from nltk.probability import FreqDist
import matplotlib.pyplot as plt

print(f"Total stopwords en español: {len(stopwords.words('spanish'))}")
print(f"Ejemplo de stopwords en español: {stopwords.words('spanish')[:10]}")

#filtramos tokens

tokens_filtrados = [token for token in tokens if token.lower() not in stopwords.words('spanish')]
print(f"Tokens después de filtrar stopwords: {len(tokens_filtrados)}")
print(f"Tokens filtrados: {tokens_filtrados}")
# Out:
# Oraciones: 4
# Oración 0: ¡Hola!
#
# Oración 1: ¿Cómo estás?
#
# Oración 2: Espero que estés teniendo un buen día niño.
#
# Oración 3: El procesamiento del lenguaje natural es increíble.
#
# Tokens: 22
# Tokens: ['¡Hola', '!', '¿Cómo', 'estás', '?', 'Espero', 'que', 'estés', 'teniendo', 'un', 'buen', 'día', 'niño', '.', 'El', 'procesamiento', 'del', 'lenguaje', 'natural', 'es', 'increíble', '.']
# Total stopwords en español: 313
# Ejemplo de stopwords en español: ['de', 'la', 'que', 'el', 'en', 'y', 'a', 'los', 'del', 'se']
# Tokens después de filtrar stopwords: 14
# Tokens filtrados: ['¡Hola', '!', '¿Cómo', '?', 'Espero', 'buen', 'día', 'niño', '.', 'procesamiento', 'lenguaje', 'natural', 'increíble', '.']
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/albertolopez/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/albertolopez/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
